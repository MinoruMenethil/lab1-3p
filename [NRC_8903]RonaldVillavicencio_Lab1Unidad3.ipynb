# %%
pip install pyodbc
# Out:
# ...
#      |████████████████████████████████| 280 kB 7.4 MB/s
# ...
#   Created wheel for pyodbc: filename=pyodbc-4.0.32-cp37-cp37m-linux_x86_64.whl size=287375 sha256=6f1c86736783008858f0cc009a5ee6272c2d6441ad4bb0c2ac1ba8c121c9ddfd
#   Stored in directory: /root/.cache/pip/wheels/2e/9c/da/8652fd42e0f662015554f00a9e96fe4f438dfd1ef59787879e
# Successfully built pyodbc
# ...

# %%
import pandas as pd
import  sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import MetaData
from datetime import datetime
import psycopg2
import pyodbc


engine = create_engine('sqlite:///chinook.db')
frameArtists = pd.read_sql_query("""select name from artists;""", 
con=engine.connect())
frameArtists
# Out:
#                                                   Name
# 0                                                AC/DC
# 1                                               Accept
# 2                                            Aerosmith
# 3                                    Alanis Morissette
# 4                                      Alice In Chains
# ..                                                 ...
# 270   Mela Tenenbaum, Pro Musica Prague & Richard Kapp
# 271                             Emerson String Quartet
# 272  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 273                                      Nash Ensemble
# 274                              Philip Glass Ensemble
#
# [275 rows x 1 columns]

# %%
df_customers = pd.read_sql_query("""SELECT FirstName, LastName, Company, Address, City, State, Country,PostalCode, Phone, Fax,Email FROM customers; """, con=engine.connect())
df_customers.head()
df_artists = pd.read_sql_query("""SELECT Name as NameArtist FROM artists;""", con=engine.connect())
df_albums = pd.read_sql_query("""SELECT Title as TitleAlbum FROM albums;""", con=engine.connect())
df_genres = pd.read_sql_query("""SELECT Name as NameGenre FROM genres;""", con=engine.connect())
df_employees = pd.read_sql_query("""SELECT LastName, FirstName, Title, BirthDate, HireDate,  Address, City, State, Country, PostalCode, Phone, Fax, Email FROM employees;""", con=engine.connect())

df_invoice_items = pd.read_sql_query("""SELECT UnitPrice, Quantity FROM invoice_items;""", con=engine.connect())
df_playlists = pd.read_sql_query("""SELECT Name as NamePlaylist FROM playlists;""", con=engine.connect())
df_location = pd.read_sql_query("""SELECT Address, City, COALESCE(State, 'N/A') as State, Country, COALESCE(PostalCode, 'N/A') as PostalCode FROM customers;""", con=engine.connect())

conn = sqlalchemy.create_engine('mssql+pyodbc://localhost/DW_Sales_Music?driver=SQL+Server+Native+Client+11.0')

df_location
# Out:
#                                      Address  ...  PostalCode
# 0            Av. Brigadeiro Faria Lima, 2170  ...   12227-000
# 1                    Theodor-Heuss-Straße 34  ...       70174
# 2                          1498 rue Bélanger  ...     H2G 1A7
# 3                           Ullevålsveien 14  ...        0171
# 4                              Klanova 9/506  ...       14700
# 5                              Rilská 3174/6  ...       14300
# 6       Rotenturmstraße 4, 1010 Innere Stadt  ...        1010
# 7                            Grétrystraat 63  ...        1000
# 8                        Sønder Boulevard 51  ...        1720
# 9                  Rua Dr. Falcão Filho, 155  ...   01007-010
# 10                        Av. Paulista, 2022  ...   01310-200
# 11                          Praça Pio X, 119  ...   20040-020
# 12                              Qe 7 Bloco G  ...   71020-677
# 13                            8210 111 ST NW  ...     T6G 2C7
# ...

# %%
df_customers.to_sql(name='dim_customers', con=conn, if_exists='append',index=False)
df_employees.to_sql(name='dim_employees', con=conn, if_exists='append',index=False)
df_genres.to_sql(name='dim_genres', con=conn, if_exists='append',index=False)
df_albums.to_sql(name='dim_albums', con=conn, if_exists='append',index=False)
df_artists.to_sql(name='dim_artists', con=conn, if_exists='append',index=False)
df_playlists.to_sql(name='dim_playlists', con=conn, if_exists='append',index=False)
df_location.to_sql(name='dim_location', con=conn, if_exists='append',index=False)
df_invoice_items.to_sql(name='dim_invoice_items', con=conn, if_exists='append',index=False)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3249         try:
# -> 3250             return fn()
#    3251         except dialect.dbapi.Error as e:
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...
